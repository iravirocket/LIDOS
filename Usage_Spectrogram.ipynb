# %%
import Spectrogram

# %%
dates = '01_22_2025'
id_lamp='lamp_2T_10m'
lamp_wav_fit0, datas, waves = Spectrogram.waterfall_plot_one(dates,dates,id_lamp,time_res=10)

# %%
id_cell='cell_2T_7V_10m'
time_res=10
Spectrogram.waterfall_plot_two(dates,dates,id_lamp,time_res,id_cell)
