# %%
import Spectrogram

# %%
dates = '02_05_2025'
id_lamp='lamp_2T_7V_3m_2'
lamp_wav_fit0, datas, waves,lamp3,wavelength = Spectrogram.waterfall_plot_one(dates,dates,id_lamp,time_res=5,t_start=50)
# Out:
# C:\Users\jackf\Desktop\Rocket Group\LIDOS_data\Spectrogram.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_lamp['xr'] = self.df_lamp['xr']*self.res

# %%
id_cell='cell_2T_7V_3m_2'
time_res=5
Spectrogram.waterfall_plot_two(dates,dates,id_lamp,time_res,id_cell,t_start=50)
# Out:
# C:\Users\jackf\Desktop\Rocket Group\LIDOS_data\Spectrogram.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_lamp['xr'] = self.df_lamp['xr']*self.res
# C:\Users\jackf\Desktop\Rocket Group\LIDOS_data\Spectrogram.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.df_lamp['xr'] = self.df_lamp['xr']*self.res
# C:\Users\jackf\Desktop\Rocket Group\LIDOS_data\Spectrogram.py:450: RuntimeWarning: invalid value encountered in true_divide
# ...
